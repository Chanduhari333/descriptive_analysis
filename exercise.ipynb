# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Set up the plot size
plt.figure(figsize=(10, 6))

# Plot histogram of 'age', separated by 'sex'
sns.histplot(data=titanic, x='age', hue='sex', multiple='stack', bins=30)

# Add titles and labels
plt.title('Age Distribution of Titanic Passengers by Sex')
plt.xlabel('Age')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
relevant_cols = ['age', 'sex', 'survived', 'pclass', 'fare']
titanic_relevant = titanic[relevant_cols]
titanic_relevant.head()
# Out:
#     age     sex  survived  pclass     fare
# 0  22.0    male         0       3   7.2500
# 1  38.0  female         1       1  71.2833
# 2  26.0  female         1       3   7.9250
# 3  35.0  female         1       1  53.1000
# 4  35.0    male         0       3   8.0500
